# %% [markdown]
# <a href="https://colab.research.google.com/github/AreebaaAli/Deep-Learning/blob/master/TOC1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
from termcolor import colored

# %%
from google.colab import files 
upload = files.upload()
# Out:
#      <input type="file" id="files-f2dc4855-d077-425b-8d3f-d5bc2b1346c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2dc4855-d077-425b-8d3f-d5bc2b1346c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving profilepicture.jpeg to profilepicture.jpeg

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img

image = img.imread('profilepicture.jpeg')
plt.title('AREEBA ALI')
plt.imshow(image)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1e54b885-6c96-44b9-bd32-e04eb788dd06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e54b885-6c96-44b9-bd32-e04eb788dd06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving storagedata.xlsx to storagedata.xlsx

# %%
xlsx = pd.ExcelFile('storagedata.xlsx')
file=pd.read_excel(xlsx)
file=pd.DataFrame(file)
print(file)
print('________________________')
print(colored('IMEI NO: 354315086259078', 'blue'))
# Out:
#         Type  Space Used In GB
# 0     Videos            1.5000
# 1     Images            1.2000
# 2  Documents            0.5410
# 3      Audio            0.0407
# 4       Apps           10.1000
# ________________________
# IMEI NO: 354315086259078

# %%
type= file['Type']
memory = file['Space Used In GB']
plt.title('HISTOGRAM OF OCCUPIED STORAGE')
plt.bar(type,memory, color='#9467bd')
# Out:
# <BarContainer object of 5 artists>

# %%
from google.colab import files 
upload = files.upload()
# Out:
#      <input type="file" id="files-02c8b4fa-214d-46bc-ba1b-876c3782cff5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02c8b4fa-214d-46bc-ba1b-876c3782cff5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving proof.jpeg to proof.jpeg

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
image = img.imread('proof.jpeg')
plt.title('PROOF')
plt.imshow(image)
